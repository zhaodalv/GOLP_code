# %%
import pandas as pd

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib as mpl
mpl.rcParams['svg.fonttype']='none'

# %%
CD8_clonal_info_T=pd.read_pickle("Revision_plot/CD8_clonal_info_T.pkl")
CD4_clonal_info_T=pd.read_pickle("Revision_plot/CD4_clonal_info_T.pkl")

# %%
import numpy as np
patient_name=[x[0] for x in CD4_clonal_info_T.index.str.split('_')]

# %%
0.893541+0.068182
# Out:
# 0.961723

# %%
CD4_clonal_info_T.to_csv("source_data/FigureS6C_CD4.txt",sep="\t")

# %%
CD8_clonal_info_T.to_csv("source_data/FigureS6C_CD8.txt",sep="\t")

# %%
x=np.arange(8)
figure=plt.figure(figsize=(8,7))
ax1=figure.add_subplot(111)
ax1.bar(x-0.25,CD4_clonal_info_T.loc[CD4_clonal_info_T['Group']==0,'Unique'],width=0.2,color='#ae24d1',label='CD4+T Biopsy Unique')
#ax1.bar(x-0.2,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'Unique'],width=0.2,color='#ae24d1',label='Biopsy Unique')

ax1.bar(x-0.25,CD4_clonal_info_T.loc[CD4_clonal_info_T['Group']==0,'Clonal'],width=0.2,bottom=CD4_clonal_info_T.loc[CD4_clonal_info_T['Group']==0,'Unique'],color='orange',label='CD4+T Biopsy Clonal')
#ax1.bar(x-0.2,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'Clonal'],width=0.2,bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'Unique'],color='orange',label='Biopsy Clonal')


ax1.bar(x-0.25,CD4_clonal_info_T.loc[CD4_clonal_info_T['Group']==0,'Shared'],width=0.2,bottom=CD4_clonal_info_T.loc[CD4_clonal_info_T['Group']==0,'U_C'],color='red',label='CD4+T Shared Clonal')
#ax1.bar(x-0.2,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'Shared'],width=0.2,bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'U_C'],color='red',label='Shared Clonal')


ax1.bar(x+0.05,CD4_clonal_info_T.loc[CD4_clonal_info_T['Group']==1,'Unique'],width=0.2,color='#24b1d1',label='CD4+T Surgery Unique')
#ax1.bar(x+0.3,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Unique'],width=0.2,color='#24b1d1',label='Surgery Unique')


ax1.bar(x+0.05,CD4_clonal_info_T.loc[CD4_clonal_info_T['Group']==1,'Clonal'],width=0.2,color='cyan',label='CD4+T Surgery Clonal',bottom=CD4_clonal_info_T.loc[CD4_clonal_info_T['Group']==1,'Unique'])
#ax1.bar(x+0.3,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Clonal'],width=0.2,color='cyan',label='Surgery Clonal',bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Unique'])

ax1.bar(x+0.05,CD4_clonal_info_T.loc[CD4_clonal_info_T['Group']==1,'Shared'],width=0.2,color='red',label='CD4+T Shared',bottom=CD4_clonal_info_T.loc[CD4_clonal_info_T['Group']==1,'U_C'])
#ax1.bar(x+0.3,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Shared'],width=0.2,color='red',label='Shared',bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'U_C'])

plt.legend(bbox_to_anchor=(1.01,1))

#
#ax1.bar(x,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Shared'],width=0.4,bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'U_C'],color='red',label='Shared Clonal')
ax1.set_xticks(x)
ax1.set_xticklabels(xlabel_cd)#ae24d1#ae24d1
#plt.legend()
figure.savefig("Supplementary_figures/CD4+T_clonal_patient.svg")

# %%
xlabel_cd=['P01','P02','P03','P04','P05','P06','P07','P08']

# %%
figure=plt.figure(figsize=(8,7))
ax1=figure.add_subplot(111)
ax1.bar(x-0.25,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'Unique'],width=0.2,color='#ae24d1',label='CD8+T Biopsy Unique')
#ax1.bar(x-0.2,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'Unique'],width=0.2,color='#ae24d1',label='Biopsy Unique')

ax1.bar(x-0.25,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'Clonal'],width=0.2,bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'Unique'],color='orange',label='CD8+T Biopsy Clonal')
#ax1.bar(x-0.2,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'Clonal'],width=0.2,bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'Unique'],color='orange',label='Biopsy Clonal')


ax1.bar(x-0.25,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'Shared'],width=0.2,bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'U_C'],color='red',label='CD8+T Shared Clonal')
#ax1.bar(x-0.2,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'Shared'],width=0.2,bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==0,'U_C'],color='red',label='Shared Clonal')


ax1.bar(x+0.05,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Unique'],width=0.2,color='#24b1d1',label='CD8+T Surgery Unique')
#ax1.bar(x+0.3,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Unique'],width=0.2,color='#24b1d1',label='Surgery Unique')


ax1.bar(x+0.05,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Clonal'],width=0.2,color='cyan',label='CD8+T Surgery Clonal',bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Unique'])
#ax1.bar(x+0.3,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Clonal'],width=0.2,color='cyan',label='Surgery Clonal',bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Unique'])

ax1.bar(x+0.05,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Shared'],width=0.2,color='red',label='CD8+T Shared',bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'U_C'])
#ax1.bar(x+0.3,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Shared'],width=0.2,color='red',label='Shared',bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'U_C'])

plt.legend(bbox_to_anchor=(1.01,1))

#
#ax1.bar(x,CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'Shared'],width=0.4,bottom=CD8_clonal_info_T.loc[CD8_clonal_info_T['Group']==1,'U_C'],color='red',label='Shared Clonal')
#ax1.xticks(x)
ax1.set_xticks(x)
ax1.set_xticklabels(xlabel_cd)#ae24d1#ae24d1
#plt.legend()
figure.savefig("Revision_plot/CD8+T_clonal_patient.svg")
